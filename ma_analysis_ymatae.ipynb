# %% [markdown]
# #### 【特許データ】※4つのCSVデータがあります
# 1. 20230503PA60999all
# - 紐づく項目「Publication number」、「Applicant(s) BvD ID Number(s)」、「Current direct owner(s) BvD ID Number(s)」、
# - 「Backward citations」…その特許が引用している引用特許のPublication numberが記載されています
# - 「Forward citations」…その特許が引用されている被引用特許のPublication numberが記載されています
# 2. 20230503PA60999abstract
# - 紐づく項目「Publication number」
# - 「Abstract」…要約です
# 3. 20230503PA60999claim
# - 紐づく項目「Publication number」
# - 「Claim」…請求項です
# 4. 20230503PAcampany4815
# - 紐づく項目「BvD ID number」、「Orbis ID number」
# - 「Current market capitalisation th JPY」…最近の時価総額です
# - 【M&Aデータ】※1つのCSVデータがあります
# 5. 20230504MA624620
# - 紐づく項目「Acquiror BvD ID number」、「Target BvD ID number」

# %%
import cugraph
import cudf
import pandas as pd
import numpy as np
import datashader as ds
import cuxfilter
import networkx as nx
import seaborn as sns
import collections as cl
import matplotlib.pyplot as plt

# %%
pa_abst_file = "./data/20230503PA60999abstract.csv"
#pa_all_file = "./data/20230503PA60999all.csv"
pa_all_file = "./data/20230524PA61332all.csv"
pa_claim_file = "./data/20230503PA60999claim.csv"
company_file = "./data/20230503PAcampany4815.csv"
ma_file = "./data/20230504MA624620.csv"

# %%
pa_abst_df = pd.read_csv(pa_abst_file)
pa_all_df = pd.read_csv(pa_all_file,low_memory=False)
pa_claim_df = pd.read_csv(pa_claim_file)
company_df = pd.read_csv(company_file)
ma_df = pd.read_csv(ma_file)

# %%
#pa_abst_df
#pa_all_df
#pa_claim_df
#pa_company_df
#ma_df

# %%
# pa_df に統合
pa_tmp_df = pd.merge(pa_all_df, pa_abst_df, on="Publication number")
pa_df = pd.merge(pa_tmp_df, pa_claim_df, on="Publication number")

# %%
#pa_df

# %%
#pd.set_option('display.max_columns', None)
pd.set_option('display.max_columns', 20)
pd.set_option("display.max_colwidth", 50)

# %%
pa_df
# Out:
#       Publication number Publication date Application number  \
# 0             AR110295A1       13/03/2019      ARP170103357A
# 1             AR118429A1       06/10/2021      ARP200100759A
# 2             AR097926A1       20/04/2016      ARP140103705A
# 3             AR101678A1       04/01/2017      ARP150102707A
# 4         AU2009251048B2       19/12/2013      AU2009251048A
# ...                  ...              ...                ...
# 55215       CN115943288A       07/04/2023    CN202180017377A
# 55216       CN115943429A       07/04/2023    CN202180043739A
# 55217       CN115931716A       07/04/2023    CN202211165002A
# 55218       CN115943424A       07/04/2023    CN202180043417A
# 55219       CN115943425A       07/04/2023    CN202080102587A
#
#       Application/filing date                   Applicant(s) name(s)  \
# 0                  30/11/2017                       SONY CORPORATION
# 1                  18/03/2020                        NEC CORPORATION
# 2                  03/10/2014              COLGATE-PALMOLIVE COMPANY
# 3                  24/08/2015                       SONY CORPORATION
# 4                  18/12/2009                               CANON KK
# ...                       ...                                    ...
# 55215              14/06/2021  Hitachi High-Technologies Corporation
# 55216              29/07/2021                 KLA-Tencor Corporation
# 55217              23/09/2022               NIDEC SANKYO CORPORATION
# 55218              25/06/2021                   FUJIFILM Corporation
# 55219              07/07/2020        MITSUBISHI ELECTRIC CORPORATION
#
#       Applicant(s) country code(s) Applicant(s) BvD ID Number(s)  \
# 0                               JP               JP5010401067252
# 1                               JP               JP7010401022916
# 2                               US                   US131815595
# 3                               JP               JP5010401067252
# 4                               JP               JP6010801003186
# ...                            ...                           ...
# 55215                           JP               JP4010401021648
# 55216                           US                   US042564110
# 55217                           JP               JP3100001018326
# 55218                           JP               JP2010401064789
# 55219                           JP               JP4010001008772
#
#              Current direct owner(s) name(s)  \
# 0                           SONY CORPORATION
# 1                            NEC CORPORATION
# 2                  COLGATE-PALMOLIVE COMPANY
# 3                           SONY CORPORATION
# 4                                   CANON KK
# ...                                      ...
# 55215  Hitachi High-Technologies Corporation
# 55216                 KLA-Tencor Corporation
# 55217               NIDEC SANKYO CORPORATION
# 55218                   FUJIFILM Corporation
# 55219        MITSUBISHI ELECTRIC CORPORATION
#
#       Current direct owner(s) country code(s)  \
# 0                                          JP
# 1                                          JP
# 2                                          US
# 3                                          JP
# 4                                          JP
# ...                                       ...
# 55215                                      JP
# 55216                                      US
# 55217                                      JP
# 55218                                      JP
# 55219                                      JP
#
#       Current direct owner(s) BvD ID Number(s) Number of backward citations  \
# 0                              JP5010401067252                            0
# 1                              JP7010401022916                            0
# 2                                  US131815595                            0
# 3                              JP5010401067252                            0
# 4                              JP6010801003186                            1
# ...                                        ...                          ...
# 55215                          JP4010401021648                            0
# 55216                              US042564110                            0
# 55217                          JP3100001018326                            0
# 55218                          JP2010401064789                            0
# 55219                          JP4010001008772                            0
#
#       Backward citations  Number of forward citations Forward citations  \
# 0                    NaN                            0               NaN
# 1                    NaN                            0               NaN
# 2                    NaN                            0               NaN
# 3                    NaN                            0               NaN
# 4            US6987883B2                            0               NaN
# ...                  ...                          ...               ...
# 55215                NaN                            0               NaN
# 55216                NaN                            0               NaN
# 55217                NaN                            0               NaN
# 55218                NaN                            0               NaN
# 55219                NaN                            0               NaN
#
#       Title language                                              Title  \
# 0                eng  APPARATUS FOR PROCESSING INFORMATION, OBSERVAT...
# 1                eng   COMPARISON APPARATUS, CONTROL METHOD AND PROGRAM
# 2                eng                  PROCESSING OF DENTINA TUBE IMAGES
# 3                eng  INFORMATION PROCESSING DEVICE, INFORMATION PRO...
# 4                eng  BACKGROUND IMAGE AND MASK ESTIMATION FOR ACCUR...
# ...              ...                                                ...
# 55215            eng  COMPUTER SYSTEM, DIMENSION MEASURING METHOD, A...
# 55216            eng  DEPTH GENERATIVE MODELS FOR OPTICAL OR OTHER M...
# 55217            eng                         HOW TO CHECK LIGHT LEAKAGE
# 55218            eng            IMAGE DATA PROCESSING DEVICE AND SYSTEM
# 55219            eng                           VISUAL FEEDBACK CONTROLS
#
#                                                 Abstract  \
# 0      An apparatus for processing the information th...
# 1      A comparison apparatus (2000) extracts an imag...
# 2      Method for quantifying dentin tubules on a den...
# 3      An information processing device includes: a g...
# 4      BACKGROUND IMAGE AND MASK ESTIMATION FOR ACCUR...
# ...                                                  ...
# 55215  The present disclosure provides a computer sys...
# 55216  The present invention provides a method and sy...
# 55217  The present invention provides an inspection m...
# 55218  The present invention provides an image data p...
# 55219  The visual feedback control device (20) has: a...
#
#                                                   Claims
# 0      Having thus especially described and determine...
# 1      CLAIMSHaving thus especially described and det...
# 2      CLAIMS1. \nA method for quantifying dentin tub...
# 3      CLAIMSHaving thus specially described and dete...
# 4      The claims defining the invention are as follo...
# ...                                                  ...
# 55215  1\n. A computer system that provides a functio...
# 55216  1\n. A system configured to select a mode of a...
# 55217  1\n. A light leakage inspection method for ins...
# 55218  1\n. An image data processing device that proc...
# 55219  1\n. A visual feedback control device, which c...
#
# [55220 rows x 18 columns]

# %%
pa_df["Current direct owner(s) BvD ID Number(s)"]
# Out:
# 0        JP5010401067252
# 1        JP7010401022916
# 2            US131815595
# 3        JP5010401067252
# 4        JP6010801003186
#               ...
# 55215    JP4010401021648
# 55216        US042564110
# 55217    JP3100001018326
# 55218    JP2010401064789
# 55219    JP4010001008772
# Name: Current direct owner(s) BvD ID Number(s), Length: 55220, dtype: object

# %%
company_ids = list(pa_df["Current direct owner(s) BvD ID Number(s)"])
# companyは";"で区切られていることがある

# %%
print(company_ids[100:200])
# Out:
# ['US951678055', 'US742747608', 'JP5120001077450', 'US305565539L', 'US201329043L', 'US299794277L', 'US243477398L', 'US252118547L', 'JP5011201010237', 'JP4011001030015', 'US149143136L', 'US370602744', 'US930621989', 'US742747608', 'US942404110', 'US470445638', 'US112308681', 'JP6010801003186', 'JP1020001071491', 'US112308681', 'US942404110', 'US128431668L', 'JP3010401026805', 'US*Z00074622', 'US310568628', 'US220760120', 'US134090555L', 'US149143136L', 'US134696824L', nan, 'US370602744', 'US134696824L', 'JP6010801003186', 'JP1020001071491', 'US942976937', 'JP6010801003186', 'US930822509', 'US163698294L', 'US220760120', 'JP4011001030015', 'JP3010401026805', 'JP4011001030015', 'US246974213L', 'JP4011001030015', 'JP5010401067252', 'US2-247393', 'JP4011001030015', 'US128490825L;US942976937', 'US942976937', 'JP6010801003186', 'US942976937', 'US169903029L', 'US221454160', 'US169541499L', 'US*Z00074622', 'US942404110', 'US146158701L', 'US164429421L', 'US020407755', 'JP6010801003186', 'US116227714GN;US942976937', 'US129438112L', 'US942404110', 'JP9120001076036', 'US188521458L', nan, 'US940890210', 'JP3010401026805', 'US942404110', 'US131722271L', 'US335234276L', 'US134214282L', 'US132615471L', 'US206004204L', 'US132615471L', 'JP5010401067252', 'US134090555L', 'JP6010801003186', 'US305907173L', 'US131722271L', 'CA273241724L', 'US930822509', 'US942976937', 'JP6010801003186', 'US134090555L', 'US201901148', 'US310568628', 'JP5010401067252', 'US134696824L', 'JP6010801003186', 'CA207028251L', 'US164429421L', 'CHCHE105815381;US942976937', 'US134696824L', 'US*110231403760', nan, 'US942976937', 'US042695240', 'US942976937', 'US123274482L;US020692322']

# %%
len(company_ids)
# Out:
# 55220

# %%
len(set(company_ids))
# Out:
# 5318

# %%
pids = list(pa_df["Publication number"])

# %%
pidcompDic = cl.defaultdict(list)
for i,pid in enumerate(pids):
    comp_str = company_ids[i]
    if comp_str is np.nan:
#        print("nan")
        comps = ["NO-NAME"]
    else:
        comps = comp_str.split(';')
        
#    print(comps)
    pidcompDic[pid] = comps
    
#print(comps）

# 目的:
# 特許番号をキー、所有者を値として格納する辞書を作成します。
# 説明:
# defaultdictを使うことで、辞書に存在しないキーへのアクセス時に空のリストを初期値として自動的に追加します。

# 目的:

# 各特許番号に対応する所有者をpidcompDicに登録します。
# 動作:

# enumerate(pids):
# 特許番号リストpidsをインデックスと特許番号のペアに変換。

# comp_str = company_ids[i]:

# 特許番号リストのインデックスiを使って、対応する所有者情報を取得します。
# if comp_str is np.nan:

# np.nan（欠損値）を確認し、欠損値の場合は"NO-NAME"を登録。
# comps = comp_str.split(';'):

# 所有者情報をセミコロン';'で分割。
# 例: '12345;67890' → ['12345', '67890']
# pidcompDic[pid] = comps:

# 特許番号pidをキー、所有者リストcompsを値として辞書に登録。

# %%
#pidcompDic

# %%
set_pids = set(pids)

# 目的:

# 特許番号のリスト（pids）からユニークな特許番号の集合（set型）を作成します。
# 説明:

# セット型は重複を除き、集合演算（例: 共通要素の抽出）に便利です。

# %%
all_c_pids = list(pa_df["Backward citations"])

# 目的:

# 特許データフレームpa_dfから「Backward citations」列をリストとして取得します。
# 説明:

# この列には各特許が参照している過去の特許番号が記載されています。

# %%
pa_df["Backward citations"][29]
# Out:
# 'US2009238438A1;US2009262993A1'

# %%
#all_c_pids

# %%
def splitCPidsStr(c_pids_str):
    c_pids_org = c_pids_str.split(';')
    c_pids = list(map(lambda x:x.strip(),c_pids_org))

    return c_pids


# 目的:

# セミコロン（;）で区切られた特許番号を分割し、余分な空白を除去したリストを返します。
# 動作:

# split(';')で文字列をリストに分割。
# strip()で各特許番号の前後の空白を削除。
# それをリストとして返す。

# %%
ref_rows = []
froms = []
tos = []
for i, pid in enumerate(pids):
    c_pids_str = all_c_pids[i]
    if c_pids_str is np.nan:
        continue
    else:
        c_pids = splitCPidsStr(c_pids_str)
#        if len(c_pids) > 1:
#            print(c_pids)

# 目的:

# 各特許番号（pid）に対し、引用特許番号を処理します。
# 動作:

# enumerate(pids)で、pidsリストのインデックスと値を取得。
# 特許pidに対応するBackward citations列の値を取得。
# 値がnp.nanの場合はスキップ。
# 値を分割して特許番号のリスト（c_pids）を作成。
# 例:

# 特許番号が '12345' で、c_pids_str が '67890; 11223' の場合、c_pids = ['67890', '11223']。
    
    and_pids = list(set_pids & set(c_pids))
# 目的:
# 現在の特許番号リストset_pidsと、引用特許番号c_pidsの共通部分を取得します。
    
    for c_pid in and_pids:
        row = [pid,c_pid]
        froms.append(pid)
        tos.append(c_pid)
        ref_rows.append(row)

# 目的:

# 現在の特許pidと引用特許c_pid間の関係を追加します。
    
    # 事業パテントスペース用にエッジを追加
    for comp in pidcompDic[pid]:
        if comp == "NO-NAME":
            continue
        else:
            row = [comp,pid]
            froms.append(comp)
            tos.append(pid)
            ref_rows.append(row)

# %%
#gdf = cudf.DataFrame({"src":froms,"dst":tos})
gdf = pd.DataFrame({"src":froms,"dst":tos})

# 目的:

# fromsとtosを元にエッジリスト形式のデータフレームを作成します。

# %%
pd.set_option("display.max_rows", 100)

# %%
gdf
# Out:
#                    src             dst
# 0      JP6010801003186  AU2009251048B2
# 1      JP3010401026805  AU2012203130B2
# 2         US127846024L  AU2010200298B2
# 3      JP4011001030015  AU2011265366B2
# 4      JP3010401026805  AU2011250825B2
# ...                ...             ...
# 60204     CN111816579B     EP2434453A2
# 60205     CN111816579B  US2018080763A1
# 60206     CN111816579B  US2005162644A1
# 60207     CN9360207637    CN111816579B
# 60208      US941672743    CN111816579B
#
# [60209 rows x 2 columns]

# %%
#G = cugraph.Graph()

# %%
#G.from_cudf_edgelist(gdf, source='src', destination='dst')
G = nx.from_pandas_edgelist(gdf, source='src', target='dst')

# %%
G.nodes()
# Out:
# NodeView(('JP6010801003186', 'AU2009251048B2', 'JP3010401026805', 'AU2012203130B2', 'US127846024L', 'AU2010200298B2', 'JP4011001030015', 'AU2011265366B2', 'AU2011250825B2', 'US133294755L', 'AU2014272171B2', 'US910425694', 'AU2011229903B2', 'AU2013273657B2', 'US275530856L', 'AU2012242587B2', 'AU2016225824B2', 'AU2012227365B2', 'AU2012227365A8', 'AU2012227365B8', 'US943267295', 'AU2015257444B2', 'US134090555L', 'AU2016335123B2', 'AU2018200411B2', 'US236942264L', 'AU2016213696B2', 'US042695240', 'AU2014223201B2', 'US470445638', 'AU2013205131B2', 'AU2017345812B2', 'US2015213302A1', 'US*Z00074622', 'US770430924', 'AU2015271906B2', 'US220760120', 'AU2017258863B2', 'US201901148', 'AU2014293238B2', 'AU2013205131A8', 'US128431668L', 'AU2015324689B2', 'AU2018282455B2', 'US2005100208A1', 'US930621989', 'AU2009250344B2', 'US942404110', 'AU2012227166B2', 'AU2008261138B2', 'AU2018220103B2', 'US9740937B2', 'US112308681', 'AU2016216614B2', 'US149143136L', 'AU2015320751B2', 'US134696824L', 'AU2016204714B2', 'AU2014204480B2', 'AU2006252019B2', 'AU2017245345B2', 'US246974213L', 'AU2017276228B2', 'AU2016243617B2', 'JP2014009997A', 'US2-247393', 'US942976937', 'AU2014230809B2', 'AU2018101226B4', 'US020407755', 'AU2009251162B2', 'AU2015265811B2', 'US2013182936A1', 'US116227714GN', 'US940890210', 'AU2011345344B2', 'AU2011250828B2', 'US131722271L', 'AU2014415227B2', 'US132615471L', 'BE1026203B1', 'AU2016349518B2', 'AU2006317424B2', 'US2005049497A1', 'US2005113680A1', 'US305907173L', 'CA273241724L', 'AU2014231341B2', 'US930822509', 'AU2018334373B2', 'AU2009251833B2', 'CA207028251L', 'AU2016265876B2', 'US164429421L', 'AU2014342259B2', 'AU2009305771B2', 'US123274482L', 'AU2008222789B2', 'US020692322', 'US132965684L', 'AU2012201854B2', 'AU2008264197B2', 'AU2013387679B2', 'CA*931357695', 'AU2009355844B2', 'US126821105L', 'AU2012319178B2', 'AU2015210915B2', 'AU2012287304B2', 'JP5010401067252', 'AU2017307694B2', 'US125715401L', 'AU2015253372B2', 'US362382580', 'AU2006203491B2', 'US130571923L', 'AU2014254219B2', 'US2002136444A1', 'US349925600L', 'AU2018204625B2', 'AU2017213456B2', 'AU2012227365A1', 'AU2016382837B2', 'AU2015210991B2', 'AU2018253501B2', 'WO2007044508A2', 'US169541499L', 'JP9120001076036', 'AU2018282261B2', 'AU2018282262B2', 'CA280801112L', 'AU2014231354B2', 'CA306105884L', 'AU2012315625B2', 'AU2015230733B2', 'AU2015252088B2', 'US128490825L', 'AU2010292181B2', 'AU2013214345B2', 'AU2014280958B2', 'AU2009250344B8', 'US169974921L', 'AU2017273560B2', 'AU2017368393B2', 'US742747608', 'AU2011280055B2', 'AU2015307191B2', 'AU2015230734B2', 'AU2012326198B2', 'AU2018330066B2', 'US169903029L', 'AU2016348404B2', 'AU2016265949B2', 'CN1304930C', 'JP5120001158218', 'CN1303570C', 'CN1319012C', 'US6549683B1', 'JP8013401006169', 'JP9180301010812', 'CN1301491C', 'JP2010401064789', 'CN100341312C', 'CN1324299C', 'US2002034317A1', 'JP2001289614A', 'JP1130001016824', 'CN100354893C', 'CN100346350C', 'JP6130001003272', 'CN100349174C', 'CN100382108C', 'JP2002342760A', 'JP4011101010841', 'US142036293L', 'CN1322792C', 'JP9011601000379', 'CN100405006C', 'JP4010001008772', 'CN100393106C', 'CN1295649C', 'JP9170001002607', 'CN100447813C', 'US242667446L', 'CN1308885C', 'CN1312508C', 'CN100456026C', 'JP1021001014481', 'CN100491910C', 'CN100365661C', 'JP4010401021648', 'CN101038670A', 'JP2180301014885', 'CN100374816C', 'US145426925L', 'CN100447527C', 'CN100458773C', 'US140689340', 'CN100442012C', 'CN100399355C', 'JP6010801007501', 'CN100520653C', 'CN100476572C', 'CN100350429C', 'CN1993708A', 'US2003021478A1', 'JP5010001008763', 'CN100529832C', 'JP7020001067105', 'CN100447814C', 'JP2010001098064', 'CN1320501C', 'US222640650', 'CN100449564C', 'CN100366224C', 'CN100456305C', 'JP2004348563A', 'JP2010801012579', 'CN100375008C', 'CN100472205C', 'CN1312902C', 'CN100345159C', 'CA*190521468507', 'CN100380390C', 'JP3090001010053', 'CN1296862C', 'CN100356369C', 'CN100396392C', 'JP2002035834A', 'JP000001020JPN', 'CN100489833C', 'CN100452093C', 'JP2003228711A', 'JP6180301013611', 'KR13011100 ...

# %%
#hdf = cugraph.connected_components(G, connection="weak")
largest_cc = max(nx.connected_components(G), key=len)

# %%
#sel_nodes_set = set(largest_cc)

# %%
#sdf = hdf["labels"].value_counts()

# %%
#sdf

# %%
#maxlabel = sdf.index[0]

# %%
#sdf.index[0]

# %%
#nodes = hdf["vertex"][hdf["labels"]==maxlabel]

# %%
#type(nodes)

# %%
#sG = cugraph.subgraph(G,nodes)
snxG = nx.subgraph(G,largest_cc)

# %%
sdf = pd.DataFrame(snxG.edges())

# %%
sG = cugraph.from_pandas_edgelist(sdf, source=0, destination=1)

# %%
# clustering
#parts, modularity_score = cugraph.leiden(sG, max_iter=10000, resolution=1)
parts, modularity_score = cugraph.louvain(sG, max_iter=10000, resolution=0.1)
# Out:
# /opt/anaconda3/lib/python3.12/site-packages/cugraph/community/louvain.py:146: FutureWarning: max_iter has been renamed max_level.  Use of max_iter is deprecated and will no longer be supported in the next releases.
#   warnings.warn(warning_msg, FutureWarning)
# /opt/anaconda3/lib/python3.12/site-packages/cugraph/community/louvain.py:154: UserWarning: max_level is set too high, clamping it down to 500.
#   warnings.warn(w_msg)

# %%
parts
# Out:
#        partition            vertex
# 0              1       US9947092B2
# 1              0     JP2007097842A
# 2              1  JPWO2020080299A1
# 3              0      CN102612634B
# 4              1       EP2423877A1
# ...          ...               ...
# 35980          0    US2016270506A1
# 35981          1       US9898659B2
# 35982          0    WO2009110323A1
# 35983          0    WO2017090170A1
# 35984          0  JPWO2019235050A1
#
# [35985 rows x 2 columns]

# %%
parts["partition"].max()
# Out:
# 15

# %%
parts["partition"].min()
# Out:
# 0

# %%
c_dicts = parts.to_dict(orient="list")

# %%
#c_dicts["vertex"]

# %%
# cDic[patent_id] = cluster_id
cDic = {}
for i, v in enumerate(c_dicts["vertex"]):
    cid = c_dicts["partition"][i]
#    if cid == ' ':
#        print("HERE")
        
    cDic[v] = cid

# %%
#cDic["JP2014085115A"]

# %%
modularity_score
# Out:
# 0.9049507975578308

# %%
#cp = sns.color_palette(n_colors=parts["partition"].max()+1)
cp = sns.color_palette("muted",n_colors=parts["partition"].max()+1)

# %%
cp
# Out:
# [(0.2823529411764706, 0.47058823529411764, 0.8156862745098039),
#  (0.9333333333333333, 0.5215686274509804, 0.2901960784313726),
#  (0.41568627450980394, 0.8, 0.39215686274509803),
#  (0.8392156862745098, 0.37254901960784315, 0.37254901960784315),
#  (0.5843137254901961, 0.4235294117647059, 0.7058823529411765),
#  (0.5490196078431373, 0.3803921568627451, 0.23529411764705882),
#  (0.8627450980392157, 0.49411764705882355, 0.7529411764705882),
#  (0.4745098039215686, 0.4745098039215686, 0.4745098039215686),
#  (0.8352941176470589, 0.7333333333333333, 0.403921568627451),
#  (0.5098039215686274, 0.7764705882352941, 0.8862745098039215),
#  (0.2823529411764706, 0.47058823529411764, 0.8156862745098039),
#  (0.9333333333333333, 0.5215686274509804, 0.2901960784313726),
#  (0.41568627450980394, 0.8, 0.39215686274509803),
#  (0.8392156862745098, 0.37254901960784315, 0.37254901960784315),
#  (0.5843137254901961, 0.4235294117647059, 0.7058823529411765),
#  (0.5490196078431373, 0.3803921568627451, 0.23529411764705882)]

# %%
cp[1]
# Out:
# (0.9333333333333333, 0.5215686274509804, 0.2901960784313726)

# %%
sG.nodes()
# Out:
# 0          WO2019087536A1
# 1           JP2015021764A
# 2          WO2015147317A1
# 3           JP2020087133A
# 4             US9311712B2
#                ...
# 35980        US10535128B2
# 35981    JPWO2017130613A1
# 35982      WO2020217878A1
# 35983        CN103810690A
# 35984         US9947092B2
# Name: 0, Length: 35985, dtype: object

# %%
df_page = cugraph.pagerank(sG)
# Out:
# /opt/anaconda3/lib/python3.12/site-packages/cugraph/link_analysis/pagerank.py:227: UserWarning: Pagerank expects the 'store_transposed' flag to be set to 'True' for optimal performance during the graph creation
#   warnings.warn(warning_msg, UserWarning)

# %%
df_page
# Out:
#        pagerank          vertex
# 0      0.000012     US9947092B2
# 1      0.000012  US2021030266A1
# 2      0.000012   JP2003021504A
# 3      0.000011    US11064963B2
# 4      0.000012  US2016331493A1
# ...         ...             ...
# 35980  0.000014    CN103597314B
# 35981  0.000014     US9497468B2
# 35982  0.000011   JP2019050462A
# 35983  0.000011   JP2019536184A
# 35984  0.000011   JP2002259972A
#
# [35985 rows x 2 columns]

# %%
df_page[df_page["pagerank"] == df_page["pagerank"].max()]
# Out:
#        pagerank           vertex
# 28385   0.02021  JP6010801003186

# %%
pd.set_option("display.max_rows", 100)

# %%
df_page.sort_values("pagerank", ascending=False)
# Out:
#        pagerank           vertex
# 28385  0.020210  JP6010801003186
# 28386  0.012569  JP5010401067252
# 28400  0.009006  JP7010401022916
# 28387  0.007908  JP2010401064789
# 28388  0.007026  JP1020001071491
# ...         ...              ...
# 15256  0.000007     US11269983B2
# 9444   0.000007     CN110662489A
# 33220  0.000007    JP2020515335A
# 33410  0.000007   WO2005106797A1
# 17713  0.000007   AU2009251162B2
#
# [35985 rows x 2 columns]

# %%
pd.set_option("display.max_colwidth", None)

# %%
pa_df["Title"][pa_df["Publication number"] == "JP6010801003186"]
# Out:
# Series([], Name: Title, dtype: object)

# %%
pa_df["Abstract"][pa_df["Publication number"] == "JP6010801003186"]
# Out:
# Series([], Name: Abstract, dtype: object)

# %%
pos_gdf = cugraph.force_atlas2(sG, max_iter=10000, pos_list=None, outbound_attraction_distribution=True, lin_log_mode=False, prevent_overlapping=False, edge_weight_influence=1.0, jitter_tolerance=1.0, barnes_hut_optimize=True, barnes_hut_theta=0.5, scaling_ratio=50.0, strong_gravity_mode=False, gravity=10, verbose=False, callback=None)
#pos_gdf = cugraph.force_atlas2(sG, max_iter=1000, pos_list=None, outbound_attraction_distribution=True, lin_log_mode=True, prevent_overlapping=False, edge_weight_influence=1.0, jitter_tolerance=1.0, barnes_hut_optimize=True, barnes_hut_theta=0.5, scaling_ratio=2.0, strong_gravity_mode=False, gravity=1.0, verbose=False, callback=None)
# 目的:

# ForceAtlas2アルゴリズムを使ってグラフのノード配置（座標）を計算。
# 説明:

# 力学的モデルに基づき、ノード間の配置を最適化。
# 結果:

# 各ノードの座標を含むデータフレーム。

# %%
pos_gdf
# Out:
#                    x              y          vertex
# 0       80227.734375  -34763.949219     US9947092B2
# 1       73313.273438 -107214.328125  US2018137551A1
# 2      353140.468750  287069.375000     US9081026B2
# 3       16191.603516    3889.853027    US10169853B2
# 4       80090.070312  -35704.210938    CN100387196C
# ...              ...            ...             ...
# 35980  -34503.652344   19744.765625  KR20160103076A
# 35981   33582.480469  -53480.800781  WO2016117018A1
# 35982  -17654.857422   72101.992188   JP2009038830A
# 35983  153379.515625  177670.296875    CN102622508A
# 35984    9352.777344   89987.992188  WO2018173108A1
#
# [35985 rows x 3 columns]

# %%
edf = sG.edges().to_pandas()

# %%
edf
# Out:
#                      0               1
# 0      JP6140001005714  WO2021002144A1
# 1         CN100456305C     US9767546B2
# 2        JP2016081212A   JP2019139433A
# 3        JP2016081212A  WO2021181715A1
# 4        JP2016081212A   JP2018017101A
# ...                ...             ...
# 27353  JP1010001027024    CN102512209A
# 27354  JP1010001027024  WO2005104953A1
# 27355  JP1010001027024   JP2001014461A
# 27356  JP1010001027024    CN100350875C
# 27357  JP1010001027024   JP2002325761A
#
# [27358 rows x 2 columns]

# %%
edf.to_csv("./edges.csv", index=False)

# %%
nxG = nx.from_pandas_edgelist(edf, source=0, target=1)

# %%
vs = list(pos_gdf["vertex"].to_pandas())
xs = list(pos_gdf["x"].to_pandas())
ys = list(pos_gdf["y"].to_pandas())

# %%
#cDic[vs[1]]

# %%
pos = {}
cposDic = cl.defaultdict(list)
cpidDic = cl.defaultdict(list)
pidcidDic = {}
node_sizes = []
node_colors = []
labels = []
for i, v in enumerate(vs):
    x = xs[i]
    y = ys[i]
    pos[v] = [x,y]
    cl_id = cDic[v]
    cposDic[cl_id].append([x,y])
    node_sizes.append(1)
    c = cp[cl_id]
    node_colors.append(c)
    labels.append(f"C{cl_id:02}")
    cpidDic[cl_id].append(v)
    pidcidDic[v] = cl_id

# 目的:

# 各ノードの座標、クラスタID、描画属性（色、サイズ）を準備。
# 説明:

# pos: ノードIDと座標を格納。
# cposDic: クラスタIDごとのノード座標を格納。
# node_sizes, node_colors: 描画用の属性。

# %%
for cid in sorted(cposDic.keys()):
    print(f"{cid}:{len(cposDic[cid])}")
#    if cid > 10:
#        break
# Out:
# 0:20846
# 1:8546
# 2:4648
# 3:1338
# 4:86
# 5:35
# 6:107
# 7:54
# 8:120
# 9:56
# 10:30
# 11:38
# 12:21
# 13:22
# 14:24
# 15:14

# %%
centroidDic = {}
for cid in cposDic.keys():
    poses = np.array(cposDic[cid])
#    print(poses.shape)
#    print(poses)
    x, y = np.average(poses, axis=0)
    centroidDic[cid] = (x,y)

# %%
nx.set_node_attributes(nxG,cDic,"clusterid")

# %%
#nx.draw(nxG,pos,with_labels=False,node_size=node_sizes)

# %%
#nx.draw_networkx_nodes(nxG,pos,nodelist=vs, node_size=node_sizes,node_color=node_colors,alpha=0.5)

# %%
nx.write_gexf(nxG,"./tech.gexf")

# %%
fig = plt.figure(figsize=(8,8))
ax = fig.add_subplot(1, 1, 1)
ax.axis('off')
ax.scatter(xs,ys,s=node_sizes,c=node_colors,alpha=0.3)
# 凡例用に空のデータをlabel付でプロットする（実際はなにもプロットしてない）
cids = sorted(centroidDic.keys())
for cid in cids:
    if cid > 10:
        break

    ax.scatter([], [], c=cp[cid], alpha=1.0, label=f"C{cid:02}")
    
ax.legend(loc="upper right")

for cid in cids:
    if cid > 10:
        break
        
    x,y = centroidDic[cid]
    ax.annotate(f"C{cid:02}",(x,y),size=8)
# Out:
# /tmp/ipykernel_3132579/2144810173.py:11: UserWarning: *c* argument looks like a single numeric RGB or RGBA sequence, which should be avoided as value-mapping will have precedence in case its length matches with *x* & *y*.  Please use the *color* keyword-argument or provide a 2D array with a single row if you intend to specify the same RGB or RGBA value for all points.
#   ax.scatter([], [], c=cp[cid], alpha=1.0, label=f"C{cid:02}")

# %%
# cluster名の抽出
from sklearn.feature_extraction.text import TfidfVectorizer

all_pids = pa_df["Publication number"].tolist()
all_titles = pa_df["Title"].tolist()
all_absts = pa_df["Abstract"].tolist()

cDocDic = cl.defaultdict(str)
vs_set = set(vs)
for i, pid in enumerate(all_pids):
    if pid not in vs_set:
        continue
        
    cid = cDic[pid]
    title = all_titles[i]
    cDocDic[cid] += f" {title}. "
#    abst = all_absts[i]
#    cDocDic[cid] += f" {title}. {abst}."

# %%
#cDocDic[40]

# %%
corpus = []
for cid in sorted(cDocDic.keys()):
    adoc = cDocDic[cid]
    corpus.append(adoc)

# %%
vectorizer = TfidfVectorizer()
X = vectorizer.fit_transform(corpus).toarray()

# %%
vocab = vectorizer.get_feature_names_out()
#print(X.toarray())

# %%
X.shape
# Out:
# (16, 6149)

# %%
#from scipy.stats import rankdata
cWDic = {}
for i in range(X.shape[0]):
#    if i > 0:
#        break
        
    vals = X[i,:]
    res = np.argsort(vals)
    big_indices = res[-20:]
    ws = []
    for idx in big_indices:
        w = vocab[idx]
        ws.append(w)
        
    cWDic[i] = ws

# %%
for cid in sorted(cWDic.keys()):
    ws = cWDic[cid]
    line = " ".join(ws)
    print(f"C{cid:02}: {line}")
# Out:
# C00: control position recording of programs object recognition for medium equipment system detection apparatus program information device method image processing and
# C01: computer medium systems in detection images information imaging methods program of system device apparatus medical for method processing image and
# C02: dimensional methods using measurement substrate program pattern detection defect measuring system of apparatus processing device for image inspection method and
# C03: to on systems camera apparatus based methods using device detection images depth in processing system of method image for and
# C04: tread vision camera estimation in vehicle wear system castings surface based using detection wet road tire for of method and
# C05: within to data source multiple auxiliary fragile image images processing security watermarks watermark systems method encoding content and methods for
# C06: on belt detection gender analysis multi systems fertility eggs unhatched plant methods detecting image agricultural system method of for and
# C07: patient fluid the pharmacy processing pill use medicine medication inspection at point assuring method counting of system clinical for and
# C08: recognition assembly apparatus analysis with response immature maize valve ear corn method methods instant system photometry image for of and
# C09: program detecting the shape underwater methods defect equipment imaging position apparatus welding device image system detection inspection for method and
# C10: target automatic visual anomaly generation balancing retrieval semantic layers water land normalized clothing automated image detection muddy tonal clustering using
# C11: depth using sensing acquisition stroke prohibited processing symptoms objects method system in video monitoring detecting methods systems patient and for
# C12: vision multi detection programs characteristics person of processing for image program system calibration camera device targetless vehicular method and game
# C13: object on determination close measurement open detection method position door dimensional it equipped garbage train and freight vehicle truck device
# C14: methods resistant base method of determination for parallelism glint image and position camera calculating board gradient vehicle alignment system wheel
# C15: wearing goods shrink bottle for balls invention title and device photography label equipment workpieces method article cap bead filler inspection

# %%
# 特化係数の算出
# CS = {(企業Aのクラスタxに属する特許数)/(企業Aの全特許数)} /{(クラスタxに属する特許数)/(全特許数)}

all_sum = 0
sums = []

for cid in sorted(cpidDic.keys()):
    pids = cpidDic[cid]
    sums.append(len(pids))
    all_sum += len(pids)
    
entire_ratio = np.array(sums)/all_sum

# %%
entire_ratio
# Out:
# array([5.79296929e-01, 2.37487842e-01, 1.29164930e-01, 3.71821592e-02,
#        2.38988467e-03, 9.72627484e-04, 2.97346116e-03, 1.50062526e-03,
#        3.33472280e-03, 1.55620397e-03, 8.33680700e-04, 1.05599555e-03,
#        5.83576490e-04, 6.11365847e-04, 6.66944560e-04, 3.89050993e-04])

# %%
sum(entire_ratio)
# Out:
# 1.0

# %%
all_comps = []
for comps in pidcompDic.values():
#    print(comps)
    all_comps.extend(comps)
    
comp_set = set(all_comps)

print(len(comp_set))
len_cids = len(cpidDic.keys())


# 会社、クラスタごとの特許数のカウント
compPCDic = {}
for comp in list(comp_set):
    compPCDic[comp] = np.zeros(len_cids)
    
for pid in pidcidDic.keys():
    cid = pidcidDic[pid]
    comps = pidcompDic[pid]
    for comp in comps:
            compPCDic[comp][cid] += 1

over_ten_comps = []
over_ten_comps_clusters = [[] for i in range(len_cids)]
for comp in list(comp_set):
    for cid in range(len_cids):
        num_patent = compPCDic[comp][cid]        
        if num_patent >= 10: 
            over_ten_comps_clusters[cid].append(comp)
# Out:
# 4823

# %%
comp_ratioDic = {}
for comp in compPCDic.keys():
    vals = compPCDic[comp]
    a_sum = sum(vals)
    ratio = vals/a_sum
    ratio = np.nan_to_num(ratio)
#    print(ratio)
#    break
    comp_ratioDic[comp] = ratio

# %%
csDic = {}
for i, comp in enumerate(comp_ratioDic.keys()):        
#    print(comp)
    ratio = comp_ratioDic[comp]
#    print(ratio)
    cs_vals = ratio / entire_ratio
#    print(entire_ratio)
#    print(cs_vals)
    csDic[comp] = cs_vals

# %%
#csDic

# %%
len(csDic.keys())
# Out:
# 4823

# %%
# クラスタごとに特化係数の高い企業を表示
comps = list(csDic.keys())

cidCsDic = {}
for cid in sorted(cWDic.keys()):
    cidCsDic[cid] = []
    for i,comp in enumerate(comps):
        cs_vals = csDic[comp]
        cs_val = cs_vals[cid]
        cidCsDic[cid].append(cs_val)

# %%
#cidCsDic

# %%
for cid in sorted(cWDic.keys()):
#    if cid > 0:
#        break 
        
    cs_vals = cidCsDic[cid]
#    print(cs_vals)
#    print(sorted(cs_vals))
    res = np.argsort(cs_vals)
#    print(res)
    compvals = []
    for idx in res[-10:]:
#        print(idx)
        cs_val = cs_vals[idx]
#        print(cs_val)
        comp = comps[idx]
        if comp in over_ten_comps_clusters[cid]:
            compval = f"{comp}:{cs_val:.04f}"
            compvals.append(compval)
        
    compvalstr = ",".join(compvals)
    print(f"C{cid:02}: {compvalstr}")
# Out:
# C00:
# C01: US*931372805:4.2107,US134696824L:4.2107
# C02:
# C03: CA31738NC:26.8946,US253929956L:26.8946,US127562502L:26.8946
# C04: US245249435L:398.1836
# C05: US262828185:815.4236
# C06:
# C07: JP7120901026083:563.8675,US220760120:666.3889
# C08: US135024120L:299.8750
# C09: US*110009553118:556.9107
# C10: CAFEB33405:1199.5000,US310506188L:1199.5000,US136764157L:1199.5000
# C11: US140430613L:946.9737,US361115800:946.9737
# C12:
# C13:
# C14:
# C15:

# %%
#cidCsDic[0]

# %%
# M&Aデータとの突合
madf = pd.read_csv("./data/20230504MA624620.csv",encoding='utf-8')

# %%
madf
# Out:
#         Deal Number          Acquiror name Acquiror country code  \
# 0        1941571578             APPLE INC.                    US
# 1        1941646802  CPI PROPERTY GROUP SA                    LU
# 2             91314    AMERICA ONLINE INC.                    US
# 3             63699  VODAFONE AIRTOUCH PLC                    GB
# 4             68143    GLAXOSMITHKLINE PLC                    GB
# ...             ...                    ...                   ...
# 624615   2007146110       ASAMA FACTORY KK                    JP
# 624616   2007146140           USS CO., LTD                    JP
# 624617   2007146147       RIA ADVISORY LLC                    US
# 624618   2007146158            AMETEK INC.                    US
# 624619   2007146222      DELLA TOFFOLA SPA                    IT
#
#        Acquiror BvD ID number  \
# 0                 US942404110
# 1                  LULB102254
# 2                 US541322110
# 3                  GB01833679
# 4                  GB03888792
# ...                       ...
# 624615        JP6180001138700
# 624616        JP3180001094608
# 624617           US288475001L
# 624618            US141682544
# 624619          IT00556470268
#
#        Pre-deal acquiror total assets th JPY Last avail. yr  \
# 0                                            35,450,779,941
# 1                                             1,304,788,370
# 2                                                      n.a.
# 3                                            16,646,803,042
# 4                                             3,164,896,749
# ...                                                     ...
# 624615                                                 n.a.
# 624616                                          196,897,000
# 624617                                                 n.a.
# 624618                                        1,693,572,745
# 624619                                           16,932,130
#
#        Pre-deal acquiror market capitalisation (Last available year) th JPY  \
# 0                                                           219,765,469,511
# 1                                                               662,897,346
# 2                                                                      n.a.
# 3                                                                      n.a.
# 4                                                                      n.a.
# ...                                                                     ...
# 624615                                                                 n.a.
# 624616                                                          677,873,000
# 624617                                                                 n.a.
# 624618                                                        4,371,464,368
# 624619                                                                 n.a.
#
#                                         Target name Target country code  \
# 0                                        TESLA INC.                  US
# 1                                     IMMOFINANZ AG                  AT
# 2                             TIME WARNER INC.(OLD)                  US
# 3                                     MANNESMANN AG                  DE
# 4         SMITHKLINE BEECHAM PLC|GLAXO WELLCOME PLC               GB|GB
# ...                                             ...                 ...
# 624615                       ICHINEN JIKCO CO., LTD                  JP
# 624616  JAPAN AUTOMOBILE AUCTION INC.|HAA KOBE INC.               JP|JP
# 624617                          TMG CONSULTING INC.                  US
# 624618         BISON GEAR & ENGINEERING CORPORATION                  US
# 624619                             COMAS SRL|F2 SRL               IT|IT
#
#                    Target BvD ID number  \
# 0                           US912197729
# 1                            ATFEB18921
# 2                           US133527249
# 3                                   NaN
# 4                 GB02337959|GB01047315
# ...                                 ...
# 624615                  JP4010001125477
# 624616  JP6011701013911|JP3140001022423
# 624617                     US266480609L
# 624618                     US140633525L
# 624619      IT01627720483|IT03593760261
#
#        Pre-deal target total assets th JPY Last avail. yr  \
# 0                                           5,707,797,981
# 1                                             581,516,200
# 2                                           5,981,825,073
# 3                                                    n.a.
# 4                                               n.a.|n.a.
# ...                                                   ...
# 624615                                          2,862,536
# 624616                                          n.a.|n.a.
# 624617                                               n.a.
# 624618                                               n.a.
# 624619                                          n.a.|n.a.
#
#        Pre-deal target market capitalisation (Last available year) th JPY  \
# 0                                                          73,214,220,011
# 1                                                             357,867,428
# 2                                                                    n.a.
# 3                                                                    n.a.
# 4                                                               n.a.|n.a.
# ...                                                                   ...
# 624615                                                               n.a.
# 624616                                                          n.a.|n.a.
# 624617                                                               n.a.
# 624618                                                               n.a.
# 624619                                                          n.a.|n.a.
#
#                                                                 Deal type  \
# 0                                                        Acquisition 100%
# 1       Acquisition increased from 35.49% to 100% Bid 3 - Increased offer
# 2                                                        Acquisition 100%
# 3                                Acquisition 100% Bid 2 - Increased offer
# 4                                                             Acquisition
# ...                                                                   ...
# 624615                                                   Acquisition 100%
# 624616                                     Acquisition unknown % and 100%
# 624617                                                   Acquisition 100%
# 624618                                                   Acquisition 100%
# 624619                                                   Acquisition 100%
#
#        Deal status Deal value th JPY Rumour date Announced date  \
# 0           Rumour    73,398,285,545  30/07/2021            NaN
# 1        Announced    26,223,285,898  03/12/2021     31/01/2022
# 2        Completed    21,241,497,142  10/01/2000     10/01/2000
# 3        Completed    20,620,512,576  13/11/1999     04/02/2000
# 4        Completed    20,060,866,791  17/01/2000     17/01/2000
# ...            ...               ...         ...            ...
# 624615   Completed              n.a.  02/08/2021     02/08/2021
# 624616   Completed              n.a.  03/08/2021     03/08/2021
# 624617   Completed              n.a.  01/05/2023     01/05/2023
# 624618   Completed              n.a.  02/05/2023     02/05/2023
# 624619   Completed              n.a.  28/04/2023     28/04/2023
#
#        Completed date Last deal status date
# 0                 NaN            30/07/2021
# 1                 NaN            31/01/2022
# 2          11/01/2001            11/01/2001
# 3          30/06/2000            30/06/2000
# 4          27/12/2000            27/12/2000
# ...               ...                   ...
# 624615     01/04/2022            01/04/2022
# 624616     01/10/2021            01/10/2021
# 624617     01/05/2023            01/05/2023
# 624618     02/05/2023            02/05/2023
# 624619     28/04/2023            28/04/2023
#
# [624620 rows x 18 columns]

# %%
ac_comps = list(madf["Acquiror BvD ID number"])
ta_comps = list(madf["Target BvD ID number"])

# %%
def splitCompsStr(ac_comps, ta_comps):
    # 複数企業間のMAを１：１対応に分解
    all_ac_comps = []
    all_ta_comps = []
    for i,ac_comp_str in enumerate(ac_comps):
        if ac_comp_str is np.nan:
            continue
            
        ta_comp_str = ta_comps[i]
        if ta_comp_str is np.nan:
            continue
            
        ac_comp_org = ac_comp_str.split('|')
        ta_comp_org = ta_comp_str.split('|')
        for an_ac_comp in ac_comp_org:
            for an_ta_comp in ta_comp_org:
                all_ac_comps.append(an_ac_comp)
                all_ta_comps.append(an_ta_comp)

    return all_ac_comps, all_ta_comps

# %%
all_ac_comps, all_ta_comps = splitCompsStr(ac_comps, ta_comps)

# %%
ma_comps = set(all_ac_comps+all_ta_comps)

# %%
pa_comps = set(comps)

# %%
#ma_comps

# %%
#ma_comps & pa_comps

# %%
# maデータの会社名突合できないことがわかった
# nayose.ipynbで名寄せを実行、結果をファイルに格納
#ndf = pd.read_csv("./date/nayose_result.csv")

# %%
#nayose_pmDic = {} # patent company -> ma company
#nayose_mpDic = {} # ma company -> patent company

#nayose_pa_comps = list(ndf["patent"])
#nayose_ma_comps = list(ndf["ma"])
#nayose_sims = list(ndf["similarity"])
#print(len(nayose_pa_comps))

#sel_nayose_pa_comps = []
#sel_nayose_ma_comps = []

#for i, sim in enumerate(nayose_sims):
#    if sim < 0.9:
#        continue
        
#    nayose_pa_comp = nayose_pa_comps[i]
#    nayose_ma_comp = nayose_ma_comps[i]
#    nayose_pmDic[nayose_pa_comp] = nayose_ma_comp
#    nayose_mpDic[nayose_ma_comp] = nayose_pa_comp
#    sel_nayose_pa_comps.append(nayose_pa_comp)
#    sel_nayose_ma_comps.append(nayose_ma_comp)
    
    
#nayose_pa_comps_set = set(sel_nayose_pa_comps)
#nayose_ma_comps_set = set(sel_nayose_ma_comps)

# %%
#len(nayose_pa_comps_set)

# %%
list_nodes = [str(n) for n in pos.keys()]

# %%
len(list_nodes)
# Out:
# 35985

# %%
set_nodes = set(list_nodes)

# %%
len(set_nodes)
# Out:
# 35985

# %%
list(set_nodes)[100:120]
# Out:
# ['US2022051042A1',
#  'WO2015163028A1',
#  'US6555401B2',
#  'JP2010276447A',
#  'WO2021141051A1',
#  'US128456725L',
#  'US2022114376A1',
#  'US10810448B2',
#  'JP2009258273A',
#  'US2002131649A1',
#  'US10651064B2',
#  'JP2020035033A',
#  'JP2019061658A',
#  'WO2013089004A1',
#  'CN105593900A',
#  'US7941275B2',
#  'WO2020100540A1',
#  'US6738518B1',
#  'KR101292897B1',
#  'US11514568B2']

# %%
#ma_at_pairs = []
#for i,ac_comp in enumerate(ac_comps):
#    ta_comp = ta_comps[i]
#    if ac_comp in nayose_ma_comps_set and ta_comp in nayose_ma_comps_set:
#        if ac_comp in set_nodes and ta_comp in set_nodes:
#            ac_comp_pa = nayose_mpDic[ac_comp]
#            ta_comp_pa = nayose_mpDic[ta_comp]
#            ma_at_pairs.append((ac_comp_pa,ta_comp_pa))

# %%
ma_at_pairs = []
for i,ac_comp in enumerate(all_ac_comps):
    if ac_comp is np.nan:
        continue
        
    ta_comp = all_ta_comps[i]
    if ta_comp is np.nan:
        continue
        
    if ac_comp == ta_comp:
        continue
        
    if len(set([ac_comp,ta_comp])&pa_comps) == 2:
        ma_at_pairs.append((ac_comp,ta_comp))

# %%
len(ma_at_pairs)
# Out:
# 268

# %%
#len(ma_at_pairs)

# %%
#print(ma_at_pairs[0:10])

# %%
#pos.keys()

# %%
# ma 座標算出
# cDic[v] = cid # cluster id
# pos[v] = [x,y]
ac_xs = []
ac_ys = []
ta_xs = []
ta_ys = []
for i,(ac_comp,ta_comp) in enumerate(ma_at_pairs):
    try:
        ac_x,ac_y = pos[ac_comp]
        ta_x,ta_y = pos[ta_comp]
    except KeyError as e:
#        print(e)
        continue
        
    ac_xs.append(ac_x)
    ac_ys.append(ac_y)
    ta_xs.append(ta_x)
    ta_ys.append(ta_y)

# %%
# PAネットワーク上でMAを可視化
fig = plt.figure(figsize=(8,8))
ax = fig.add_subplot(1, 1, 1)
ax.axis('off')
ax.scatter(xs,ys,s=node_sizes,c=node_colors,alpha=0.3)
ax.scatter(ta_xs,ta_ys,s=[50]*len(ta_xs),marker='+',c="blue",alpha=1.0)
ax.scatter(ac_xs,ac_ys,s=[50]*len(ac_xs),marker='+',c="red",alpha=1.0)

# 凡例用に空のデータをlabel付でプロットする（実際はなにもプロットしてない）
cids = sorted(centroidDic.keys())
for cid in cids:
    if cid > 10:
        break

    ax.scatter([], [], c=cp[cid], alpha=1.0, label=f"C{cid:02}")
    
ax.legend(loc="upper right")

for cid in cids:
    if cid > 10:
        break
        
    x,y = centroidDic[cid]
    ax.annotate(f"C{cid:02}",(x,y),size=8)
# Out:
# /tmp/ipykernel_3132579/422160304.py:15: UserWarning: *c* argument looks like a single numeric RGB or RGBA sequence, which should be avoided as value-mapping will have precedence in case its length matches with *x* & *y*.  Please use the *color* keyword-argument or provide a 2D array with a single row if you intend to specify the same RGB or RGBA value for all points.
#   ax.scatter([], [], c=cp[cid], alpha=1.0, label=f"C{cid:02}")

# %%
# 距離の評価
#    ac_xs.append(ac_x)
#    ac_ys.append(ac_y)
#    ta_xs.append(ta_x)
#    ta_ys.append(ta_y)

distances = []
for i,ac_x in enumerate(ac_xs):
    ac_y = ac_ys[i]
    ta_x = ta_xs[i]
    ta_y = ta_ys[i]
    distance = ((ta_x - ac_x)**2 + (ta_y - ta_x)**2)**0.5
    distances.append(distance)

# %%
np.average(distances)
# Out:
# 199096.76458392592

# %%
all_patent_companies = []
for comp_list in pidcompDic.values():
    for comp in comp_list:
        all_patent_companies.append(comp)
        
all_patent_companies_set = set(all_patent_companies)

# %%
pos_companies = list(set(list(pos.keys())) & all_patent_companies_set)

# %%
import random

rand_distances = []
rand_ma_at_pairs = []
for i,ac_x in enumerate(ac_xs):
    ac_comp,ta_comp = random.sample(pos_companies,2)
    rand_ma_at_pairs.append((ac_comp,ta_comp))
    ac_x, ac_y = pos[ac_comp]
    ta_x, ta_y = pos[ta_comp]
    distance = ((ta_x - ac_x)**2 + (ta_y - ta_x)**2)**0.5
    rand_distances.append(distance)

# %%
np.average(rand_distances)
# Out:
# 350684.1992500368

# %%
all_distances = distances + rand_distances

#bins = np.linspace(min(all_distances), max(all_distances), 50)
bins = np.linspace(0,0.5e6, 100)

plt.hist(rand_distances, bins, alpha = 0.5, label='Random')
plt.hist(distances, bins, alpha = 0.5, label='M&A')
plt.legend(loc='upper right')

plt.show()

# %%
# クラスタ内MA数の割合
# ma_at_pairs
# rand_ma_at_pairs
# cDic[v] = cid

num_clusters = len(set(cDic.values()))
print(num_clusters)

ma_cl_counts = np.zeros((num_clusters,num_clusters),dtype=np.float32)
# Out:
# 16

# %%
#cDic

# %%
all_c = 0
hit_c = 0
for ac_comp, ta_comp in ma_at_pairs:
    all_c += 1
    try:
        ac_cid = cDic[ac_comp]
        ta_cid = cDic[ta_comp]
        hit_c += 1
#        print(ac_cid)
    except KeyError as e:
#        print(e)
        continue
        
#    print(ac_cid)
#    print(ta_cid)
#    print("")
    ma_cl_counts[ac_cid,ta_cid] += 1
    
print(f"{hit_c}/{all_c}")
# Out:
# 123/268

# %%
import random

rand_ma_at_pairs = []
for i in range(0,len(ma_at_pairs)*10,1):
    ac_comp,ta_comp = random.sample(pos_companies,2)
    rand_ma_at_pairs.append((ac_comp,ta_comp))
    ac_x, ac_y = pos[ac_comp]
    ta_x, ta_y = pos[ta_comp]
    distance = ((ta_x - ac_x)**2 + (ta_y - ta_x)**2)**0.5
    rand_distances.append(distance)

# %%
rand_ma_cl_counts = np.zeros((num_clusters,num_clusters),dtype=np.float32)
#print(rand_ma_at_pairs)
for ac_comp, ta_comp in rand_ma_at_pairs:
    try:
        ac_cid = cDic[ac_comp]
        ta_cid = cDic[ta_comp]
    except KeyError as e:
        print(e)
        continue
        
#    print(ac_cid)
#    print(ta_cid)
#    print("")
    rand_ma_cl_counts[ac_cid,ta_cid] += 1

# %%
rand_ma_cl_counts += 10

# %%
fig, ax = plt.subplots()
sns.heatmap(ma_cl_counts[0:20,0:20],cmap="Reds")
#ax.invert_yaxis()
ax.xaxis.tick_top()

ax.set_xlabel("Target Company Cluster")
ax.set_ylabel("Acquiror Company Cluster")

# タイトルを設定する。
ax.set_title("M&A counts among Clusters")
# Out:
# Text(0.5, 1.0, 'M&A counts among Clusters')

# %%
fig, ax = plt.subplots()
sns.heatmap(rand_ma_cl_counts[0:20,0:20],cmap="Reds")
#ax.invert_yaxis()
ax.xaxis.tick_top()

ax.set_xlabel("Target Company Cluster")
ax.set_ylabel("Acquiror Company Cluster")

# タイトルを設定する。
ax.set_title("Random M&A counts among Clusters")
# Out:
# Text(0.5, 1.0, 'Random M&A counts among Clusters')

# %%
ma_cl_ratio = ma_cl_counts / rand_ma_cl_counts

# %%
#ma_cl_ratio
ma_cl_ratio = np.nan_to_num(ma_cl_ratio, nan=0)
#ma_cl_ratio[ma_cl_ratio < 1e-9] = 0

# %%
np.amax(ma_cl_ratio)
# Out:
# 0.2777778

# %%
sns.heatmap(ma_cl_ratio[0:20,0:20],cmap="Reds")
#ax.invert_yaxis()
ax.xaxis.tick_top()

ax.set_xlabel("Target Company Cluster")
ax.set_ylabel("Acquiror Company Cluster")

# タイトルを設定する。
ax.set_title("MA/Random counts ratio among Clusters")
# Out:
# Text(0.5, 1.0, 'MA/Random counts ratio among Clusters')

# %%
# ratioの高いMAの抽出
#max_idx = ind = np.unravel_index(np.argmax(ma_cl_ratio, axis=None), ma_cl_ratio.shape)
#max_idx
maratios = []
for i in range(0,num_clusters,1):
    for j in range(0,num_clusters,1):
        ratio = ma_cl_ratio[i,j]
        c = ma_cl_counts[i,j]
        if ratio == 0:
            continue
            
        row = (i,j,c,ratio)
        maratios.append(row)

# %%
rdf = pd.DataFrame(maratios)
rdf.columns = ["AcqCl","TarCl","MA count","Ratio"]

# %%
pd.set_option('display.max_rows', 100)

rdf.sort_values("Ratio",ascending=False)
# Out:
#     AcqCl  TarCl  MA count     Ratio
# 14      3      3       5.0  0.277778
# 10      2      2       6.0  0.107143
# 19     11     11       1.0  0.100000
# 18     11      3       1.0  0.100000
# 16      7      7       1.0  0.100000
# 20     12      3       1.0  0.100000
# 13      3      2       2.0  0.086957
# 4       1      1      26.0  0.086667
# 15      7      1       1.0  0.083333
# 17     11      0       1.0  0.083333
# 0       0      0      39.0  0.066895
# 7       1      8       1.0  0.055556
# 9       2      1       5.0  0.041667
# 6       1      3       2.0  0.037037
# 5       1      2       4.0  0.031496
# 1       0      1      11.0  0.026764
# 2       0      2       4.0  0.021739
# 12      3      1       1.0  0.021277
# 11      3      0       1.0  0.018868
# 8       2      0       3.0  0.018182
# 3       1      0       7.0  0.017500

# %%
#nayose_pmDic

# %%
comp_ids = list(company_df["BvD ID number"])
comp_names = list(company_df["Company name Latin alphabet"])

# %%
compDic = {}
for i, comp_id in enumerate(comp_ids):
    comp_name = comp_names[i]
    compDic[comp_id] = comp_name

# %%
#compDic

# %%
# MA抽出
def clfilterMA(sel_acq_cid,sel_tar_cid,cDic,compDic):
    res = []
    for i,(ac_comp, ta_comp) in enumerate(ma_at_pairs):
#        print(ta_comp)
        try:
            ac_cid = cDic[ac_comp]
            ta_cid = cDic[ta_comp]
        except KeyError as e:
#            print(e)
            continue
            
        if ac_cid == sel_acq_cid and ta_cid == sel_tar_cid:
            if ac_comp in compDic.keys() and ta_comp in compDic.keys():
                ma_acq_name = compDic[ac_comp]
                ma_tar_name = compDic[ta_comp]
                res.append((ma_acq_name,ma_tar_name))
        
    return res

# %%
resMA = clfilterMA(0,0,cDic,compDic)
resMA
# Out:
# [('NIPPON TELEGRAPH AND TELEPHONE CORPORATION', 'NTT DATA CORPORATION'),
#  ('SOFTBANK GROUP CORP', 'SOFTBANK CORP'),
#  ('IHI CORPORATION', 'WESTINGHOUSE ELECTRIC CO'),
#  ('MITSUBISHI HEAVY INDUSTRIES LTD', 'WESTINGHOUSE ELECTRIC CO'),
#  ('PANASONIC HOLDINGS CORPORATION', 'SANYO ELECTRIC CO.,LTD.'),
#  ('NIDEC CORPORATION', 'NIDEC MOBILITY CORPORATION'),
#  ('ALPS ALPINE CO.,LTD.', 'ALPINE ELECTRONICS, INC.'),
#  ('RICOH CO LTD', 'PFU LIMITED'),
#  ('LATTICE SEMICONDUCTOR CORP', 'SILICON IMAGE INC'),
#  ('MITSUBISHI HEAVY INDUSTRIES LTD', 'MITSUBISHI AIRCRAFT CORPORATION'),
#  ('NAVER CORPORATION', 'A HOLDINGS CORPORATION'),
#  ('FUJIFILM HOLDINGS CORPORATION', 'FUJIFILM TOYAMA CHEMICAL CO.,LTD.'),
#  ('CANON MARKETING JAPAN INC.', 'CANON IT SOLUTIONS INC.'),
#  ('FUJI SOFT INCORPORATED', 'CYBERNET SYSTEMS COMPANY LIMITED'),
#  ('CANON INCORPORATED', 'CANON MACHINERY INC.'),
#  ('SILICON IMAGE INC', 'SIBEAM INC'),
#  ('ALARM.COM HOLDINGS, INC.', 'ENERGYHUB INC'),
#  ('PANASONIC HOLDINGS CORPORATION', 'PANASONIC ELEVATOR CO.,LTD.'),
#  ('JVC KENWOOD CORPORATION', 'VICTOR COMPANY OF JAPAN LTD'),
#  ('HITACHI INFORMATION & TELECOMMUNICATION ENGINEERING, LTD.',
#   'HITACHI COMPUTER PERIPHERALS CO.,LTD.'),
#  ('NIDEC CORPORATION', 'NIDEC ELESYS CORPORATION'),
#  ('NEC SOLUTION INNOVATORS,LTD.', 'NEC SYSTEM TECHNOLOGIES LTD'),
#  ('NEC SOLUTION INNOVATORS,LTD.', 'NEC SOFTWARE CHUBU LTD'),
#  ('TOYOTA MOTOR CORPORATION', 'K.K. TO TA I T HIRAKI FA SE N TA'),
#  ('KOITO MANUFACTURING CO., LTD.', 'KI HOLDINGS CO LTD'),
#  ('NTT DOCOMO,INC.', 'NTT COMMUNICATIONS CORPORATION'),
#  ('NTT DOCOMO,INC.', 'NTT COMWARE CORPORATION'),
#  ('OPTEX GROUP COMPANY LIMITED', 'MITSUTEC .,LTD.'),
#  ('NIDEC CORPORATION', 'NIDEC MACHINE TOOL CORPORATION'),
#  ('HITACHI SOLUTIONS CREATE,LTD.', 'HITACHI SOLUTIONS SERVICE K.K.'),
#  ('TOYOTA MOTOR CORPORATION', 'K.K. TO TA I T HIRAKI FA SE N TA'),
#  ('HITACHI SOLUTIONS,LTD.', 'HITACHI SOLUTIONS TECHNOLOGY, LTD.'),
#  ('AISIN CORPORATION', 'A I SHI N . E I . DA BU RI YU K.K.'),
#  ('KYOCERA CORPORATION', 'KYOSERAESUOSHI KK'),
#  ('OKI ELECTRIC INDUSTRY CO LTD', 'K.K. OKI DE TA'),
#  ('AISIN CORPORATION', 'K.K. E KU SU . RI SA CHI'),
#  ('NIRECO CORPORATION', 'SEIBU ELECTRIC CORPORATION.'),
#  ('NIDEC CORPORATION', 'NIDEC MACHINE TOOL CORPORATION'),
#  ('OMRON CORPORATION', 'KIRIN TECHNO-SYSTEM COMPANY.LIMITED')]

# %%
resMA = clfilterMA(1,1,cDic,compDic)
resMA
# Out:
# [('UNITED STATES GOVERNMENT', 'AMERICAN INTERNATIONAL GROUP INC.'),
#  ('HOLOGIC INC', 'CYTYC CORP'),
#  ('HOLOGIC INC', 'GEN-PROBE INCORPORATED'),
#  ('HILL-ROM HOLDINGS, INC.', 'WELCH ALLYN INC'),
#  ('KONINKLIJKE PHILIPS N.V.', 'VOLCANO CORPORATION'),
#  ('BAXTER INTERNATIONAL INC', 'HILL-ROM HOLDINGS, INC.'),
#  ('HOLOGIC INC', 'THIRD WAVE TECHNOLOGIES INC'),
#  ('ATTACHMATE CORPORATION', 'NETIQ CORP'),
#  ('OLYMPUS CORPORATION', 'EVIDENT CORPORATION'),
#  ('HILL-ROM HOLDINGS, INC.', 'MORTARA INSTRUMENT INC'),
#  ('GENERAL ELECTRIC COMPANY', 'ICAD, INC.'),
#  ('FUKU SHI FU I RU MU RU SU KE A MA NI YU FU A KU CHI YA RI N GU K.K.',
#   'HITACHI ALOKA MEDICAL LTD'),
#  ('ACCURAY INCORPORATED', 'TOMOTHERAPY INCORPORATED'),
#  ('HILL-ROM HOLDINGS, INC.', 'VOALTE INC'),
#  ('FEI COMPANY', 'DCG SYSTEMS INC'),
#  ('HILL-ROM HOLDINGS, INC.', 'BREATHE TECHNOLOGIES INC'),
#  ('SEASPINE HOLDINGS CORPORATION', '7D SURGICAL INC'),
#  ('PROGENICS PHARMACEUTICALS INC', 'MOLECULAR INSIGHT PHARMACEUTICALS, INC.'),
#  ('PROGENICS PHARMACEUTICALS INC', 'EXINI DIAGNOSTICS AKTIEBOLAG'),
#  ('BAUSCH & LOMB INCORPORATED', 'TECHNOLAS PERFECT VISION GMBH'),
#  ('KONICA MINOLTA INC', 'KONICA MINOLTA MEDICAL & GRAPHIC,INC.'),
#  ('KONICA MINOLTA INC', 'KO NI KA MI NO RU TA SOFTWARE U E A CHU HUI SHRINE'),
#  ('SALIENT IMAGING', 'THE MEDIPATTERN CORPORATION'),
#  ('HILL-ROM HOLDINGS, INC.', 'ANODYNE MEDICAL DEVICE INC')]

# %%
resMA = clfilterMA(0,1,cDic,compDic)
resMA
# Out:
# [('CANON INCORPORATED', 'CANON MEDICAL SYSTEMS CORPORATION'),
#  ('SIEMENS AG', 'ICAD, INC.'),
#  ('OBAYASHI CORPORATION', 'OBAYASHI ROAD CORPORATION'),
#  ('EIZO CORPORATION', 'CARINA SYSTEM CO., LTD.')]

# %%
resMA = clfilterMA(5,0,cDic,compDic)
resMA
# Out:
# []

# %%
resMA = clfilterMA(10,0,cDic,compDic)
resMA
# Out:
# []

# %%
resMA = clfilterMA(0,11,cDic,compDic)
resMA
# Out:
# []

# %%
#オリジナル分析
import networkx as nx
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
#1. セミコロン区切りの特許番号を分割
def split_citations(citations):
    if pd.isna(citations):
        return []
    return [cit.strip() for cit in citations.split(';')]

# %%
# 2. 特許データの引用列を分割
pa_df['Backward citations split'] = pa_df['Backward citations'].apply(split_citations)

# %%
# 3. グラフエッジリストの作成
edges = []
for _, row in pa_df.iterrows():
    citing_patent = row['Publication number']
    cited_patents = row['Backward citations split']
    for cited_patent in cited_patents:
        edges.append((cited_patent, citing_patent))  # 引用元 -> 引用先

# %%
# 4. グラフ作成
G = nx.DiGraph()  # 有向グラフ
G.add_edges_from(edges)

# %%
# 5. 次数中心性（引用されている数）と近傍中心性（引用を辿って根っこにあるもの）を計算
degree_centrality = nx.degree_centrality(G)  # 次数中心性

# %%
closeness_centrality = nx.closeness_centrality(G)  # 近傍中心性

# %%
# 6. データフレームにまとめる
centrality_df = pd.DataFrame({
    'Publication number': list(degree_centrality.keys()),
    'Degree Centrality': list(degree_centrality.values()),
    'Closeness Centrality': [closeness_centrality.get(node, 0) for node in degree_centrality.keys()]
})

# %%
# 7. 結果を保存
centrality_df.sort_values(by='Degree Centrality', ascending=False, inplace=True)
centrality_df.to_csv("centrality_analysis.csv", index=False)

# %%
# 上位10件を表示
print(centrality_df.head(10))
# Out:
#        Publication number  Degree Centrality  Closeness Centrality
# 129728        US9560221B2           0.007751              0.007751
# 119588        US9584681B2           0.007694              0.007694
# 98230         US9544451B2           0.007689              0.007689
# 149366       US10593130B2           0.005760              0.005675
# 202668       US11403887B2           0.005694              0.005675
# 128572        US9746559B2           0.005378              0.005319
# 164359       US10830920B2           0.005321              0.005365
# 186596       US11099294B2           0.005321              0.005365
# 151004       US10422919B2           0.005298              0.005343
# 154332       US10509142B2           0.005298              0.005343

# %%
# 8. ばねモデルのレイアウトを計算
pos = nx.spring_layout(G, k=0.1, iterations=50)

# %%
# 9. グラフの可視化
plt.figure(figsize=(12, 12))
nx.draw(
    G,
    pos,
    with_labels=False,  # ノードラベルは非表示
    node_size=[v * 1000 for v in degree_centrality.values()],  # 次数中心性に基づくノードサイズ
    node_color=list(closeness_centrality.values()),  # 近傍中心性に基づくノード色
    cmap=plt.cm.viridis,  # 色マップを設定
    edge_color="gray",
    alpha=0.6,
    arrows=True
)

# %%
# カラーバーを追加
sm = plt.cm.ScalarMappable(cmap=plt.cm.viridis, norm=plt.Normalize(vmin=min(closeness_centrality.values()), vmax=max(closeness_centrality.values())))
sm.set_array([])
plt.colorbar(sm, label="Closeness Centrality")

# タイトル設定
plt.title("Citation Network with Centralities")
plt.show()

# %%
#ページランクの計算
# 1. PageRankの計算
pagerank_scores = nx.pagerank(G, alpha=0.85)

# %%
# 2. データフレームにPageRankスコアを追加
centrality_df['PageRank'] = centrality_df['Publication number'].map(pagerank_scores)

# %%
# 3. データフレームをPageRankスコアでソート
centrality_df.sort_values(by='PageRank', ascending=False, inplace=True)

# %%
# 4. 結果を保存
centrality_df.to_csv("centrality_with_pagerank.csv", index=False)

# %%
# 上位10件を表示
print(centrality_df.head(10))
# Out:
#        Publication number  Degree Centrality  Closeness Centrality  PageRank
# 124691        US9858668B2           0.005137              0.005152  0.002022
# 127729        US9779452B1           0.004071              0.004073  0.001892
# 169456       US10842380B2           0.002934              0.003379  0.001650
# 123600        US9943278B2           0.004071              0.004076  0.001584
# 199114       US11339887B2           0.003104              0.003104  0.001499
# 161861       US10517482B2           0.004401              0.004300  0.001415
# 170206       US10885514B1           0.002840              0.002810  0.001387
# 146095        US9760776B1           0.002915              0.002892  0.001311
# 129728        US9560221B2           0.007751              0.007751  0.001174
# 119588        US9584681B2           0.007694              0.007694  0.001154

# %%
import networkx as nx
import pandas as pd

# 1. セミコロン区切りの特許番号を分割
def split_citations(citations):
    if pd.isna(citations):
        return []  # NaNの場合は空リストを返す
    return [cit.strip() for cit in citations.split(';')]

# %%
# 2. 特許データの引用列を分割
pa_df['Backward citations split'] = pa_df['Backward citations'].apply(split_citations)

# %%
# 3. グラフエッジリストの作成
edges = []
for _, row in pa_df.iterrows():
    citing_patent = row['Publication number']
    cited_patents = row['Backward citations split']
    for cited_patent in cited_patents:
        edges.append((cited_patent, citing_patent))  # 引用元 -> 引用先

# %%
# 4. グラフ作成
G = nx.DiGraph()  # 有向グラフ
G.add_edges_from(edges)

# %%
# 5. 基点の特定
# すべてのノードをチェックし、入力エッジ（引用されている）がないノードを基点として特定
roots = [node for node in G.nodes if G.in_degree(node) == 0]

# %%
# 6. 結果をデータフレームにまとめる
roots_df = pd.DataFrame({'Root Publication number': roots})
roots_df.to_csv("citation_roots.csv", index=False)

# %%
# 7. 結果を表示
print("引用の基点（ルート特許）の数:", len(roots))
print("引用の基点:")
print(roots_df.head(10))
# Out:
# 引用の基点（ルート特許）の数: 178705
# 引用の基点:
#   Root Publication number
# 0             US6987883B2
# 1              US5321768A
# 2          US2004151364A1
# 3          US2004130709A1
# 4          US2004101161A1
# 5             US6741731B1
# 6          US2009270169A1
# 7              US5729666A
# 8          US2005213114A1
# 9          WO2012136345A2
